# %%
import pandas as pd
import numpy as np
import csv

df=pd.read_csv(r'C:/Users/hp/Datascience/Housing_project-train.csv')
df.head()
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  127         120       RL          NaN     4928   Pave   NaN      IR1
# 1  889          20       RL         95.0    15865   Pave   NaN      IR1
# 2  793          60       RL         92.0     9920   Pave   NaN      IR1
# 3  110          20       RL        105.0    11751   Pave   NaN      IR1
# 4  422          20       RL          NaN    16635   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 4         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df_test=pd.read_csv(r'C:/Users/hp/Datascience/Housing_project-test.csv')
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL         86.0    14157   Pave   NaN      IR1
# 1  1018         120       RL          NaN     5814   Pave   NaN      IR1
# 2   929          20       RL          NaN    11838   Pave   NaN      Reg
# 3  1148          70       RL         75.0    12000   Pave   NaN      Reg
# 4  1227          60       RL         86.0    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 0         HLS    AllPub  ...           0        0    NaN   NaN         NaN
# 1         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 2         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 3         Bnk    AllPub  ...           0        0    NaN   NaN         NaN
# 4         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
df_test.drop("Id",axis=1,inplace=True)

# %%
df.drop("Id",axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 79 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     292 non-null    int64
#  1   MSZoning       292 non-null    object
#  2   LotFrontage    247 non-null    float64
#  3   LotArea        292 non-null    int64
#  4   Street         292 non-null    object
#  5   Alley          14 non-null     object
#  6   LotShape       292 non-null    object
#  7   LandContour    292 non-null    object
#  8   Utilities      292 non-null    object
#  9   LotConfig      292 non-null    object
#  10  LandSlope      292 non-null    object
#  11  Neighborhood   292 non-null    object
#  12  Condition1     292 non-null    object
#  13  Condition2     292 non-null    object
#  14  BldgType       292 non-null    object
#  15  HouseStyle     292 non-null    object
#  16  OverallQual    292 non-null    int64
# ...

# %%
df_test.drop("PoolQC",axis=1,inplace=True)
df_test.drop("Fence",axis=1,inplace=True)
df_test.drop("MiscFeature",axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1168 entries, 0 to 1167
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1168 non-null   int64
#  1   MSZoning       1168 non-null   object
#  2   LotFrontage    954 non-null    float64
#  3   LotArea        1168 non-null   int64
#  4   Street         1168 non-null   object
#  5   Alley          77 non-null     object
#  6   LotShape       1168 non-null   object
#  7   LandContour    1168 non-null   object
#  8   Utilities      1168 non-null   object
#  9   LotConfig      1168 non-null   object
#  10  LandSlope      1168 non-null   object
#  11  Neighborhood   1168 non-null   object
#  12  Condition1     1168 non-null   object
#  13  Condition2     1168 non-null   object
#  14  BldgType       1168 non-null   object
#  15  HouseStyle     1168 non-null   object
#  16  OverallQual    1168 non-null   int64
# ...

# %%
df.drop("PoolQC",axis=1,inplace=True)
df.drop("Fence",axis=1,inplace=True)
df.drop("MiscFeature",axis=1,inplace=True)

# %%
df.shape
# Out:
# (1168, 77)

# %%
for col in df.columns:
    if df[col].dtypes=="object":
        if df[col].any()==np.nan:
            df[col]=df[col].fillna(df[col].mode()[0],inplace=True)
   
        
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0         120       RL          NaN     4928   Pave   NaN      IR1
# 1          20       RL         95.0    15865   Pave   NaN      IR1
# 2          60       RL         92.0     9920   Pave   NaN      IR1
# 3          20       RL        105.0    11751   Pave   NaN      IR1
# 4          20       RL          NaN    16635   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 0         Lvl    AllPub    Inside  ...             0         0           0
# 1         Lvl    AllPub    Inside  ...             0         0         224
# 2         Lvl    AllPub   CulDSac  ...             0         0           0
# 3         Lvl    AllPub    Inside  ...             0         0           0
# 4         Lvl    AllPub       FR2  ...             0         0           0
#
#   PoolArea MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
for col in df_test.columns:
    if df_test[col].dtypes=="object":
        if df_test[col].any()==np.nan:
            df_test[col]=df_test[col].fillna(df_test[col].mode()[0],inplace=True)
   
        
df_test.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          20       RL         86.0    14157   Pave   NaN      IR1
# 1         120       RL          NaN     5814   Pave   NaN      IR1
# 2          20       RL          NaN    11838   Pave   NaN      Reg
# 3          70       RL         75.0    12000   Pave   NaN      Reg
# 4          60       RL         86.0    14598   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# 0         HLS    AllPub    Corner  ...          51             0         0
# 1         Lvl    AllPub   CulDSac  ...           0             0         0
# 2         Lvl    AllPub    Inside  ...         151             0         0
# 3         Bnk    AllPub    Inside  ...           0             0         0
# 4         Lvl    AllPub   CulDSac  ...          18             0         0
#
#   ScreenPorch PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1168 entries, 0 to 1167
# Data columns (total 77 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1168 non-null   int64
#  1   MSZoning       1168 non-null   object
#  2   LotFrontage    954 non-null    float64
#  3   LotArea        1168 non-null   int64
#  4   Street         1168 non-null   object
#  5   Alley          77 non-null     object
#  6   LotShape       1168 non-null   object
#  7   LandContour    1168 non-null   object
#  8   Utilities      1168 non-null   object
#  9   LotConfig      1168 non-null   object
#  10  LandSlope      1168 non-null   object
#  11  Neighborhood   1168 non-null   object
#  12  Condition1     1168 non-null   object
#  13  Condition2     1168 non-null   object
#  14  BldgType       1168 non-null   object
#  15  HouseStyle     1168 non-null   object
#  16  OverallQual    1168 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# MSSubClass         0
# MSZoning           0
# LotFrontage      214
# LotArea            0
# Street             0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 77, dtype: int64

# %%
df.fillna("0")
# Out:
#       MSSubClass MSZoning LotFrontage  LotArea Street Alley LotShape  \
# 0            120       RL           0     4928   Pave     0      IR1
# 1             20       RL        95.0    15865   Pave     0      IR1
# 2             60       RL        92.0     9920   Pave     0      IR1
# 3             20       RL       105.0    11751   Pave     0      IR1
# 4             20       RL           0    16635   Pave     0      IR1
# ...          ...      ...         ...      ...    ...   ...      ...
# 1163          20       RL           0     9819   Pave     0      IR1
# 1164          20       RL        67.0     8777   Pave     0      Reg
# 1165         160       RL        24.0     2280   Pave     0      Reg
# 1166          70  C (all)        50.0     8500   Pave  Pave      Reg
# 1167          60       RL           0     7861   Pave     0      IR1
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
df_test.fillna("0")
# Out:
#      MSSubClass MSZoning LotFrontage  LotArea Street Alley LotShape  \
# 0            20       RL        86.0    14157   Pave     0      IR1
# 1           120       RL           0     5814   Pave     0      IR1
# 2            20       RL           0    11838   Pave     0      Reg
# 3            70       RL        75.0    12000   Pave     0      Reg
# 4            60       RL        86.0    14598   Pave     0      IR1
# ..          ...      ...         ...      ...    ...   ...      ...
# 287          20       RL        78.0    10206   Pave     0      Reg
# 288          20       RL        57.0     9245   Pave     0      IR2
# 289          20       RL           0    11241   Pave     0      IR1
# 290          50       RM        50.0     5000   Pave     0      Reg
# 291         160       RM        21.0     1953   Pave     0      Reg
#
#     LandContour Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# ...

# %%
for col in df.columns:
    if df[col].dtypes=='object':
        df[col].fillna(df[col].mode()[0],inplace=True)

# %%
for col in df_test.columns:
    if df_test[col].dtypes=='object':
        df_test[col].fillna(df_test[col].mode()[0],inplace=True)
df_test.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          20       RL         86.0    14157   Pave  Grvl      IR1
# 1         120       RL          NaN     5814   Pave  Grvl      IR1
# 2          20       RL          NaN    11838   Pave  Grvl      Reg
# 3          70       RL         75.0    12000   Pave  Grvl      Reg
# 4          60       RL         86.0    14598   Pave  Grvl      IR1
#
#   LandContour Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# 0         HLS    AllPub    Corner  ...          51             0         0
# 1         Lvl    AllPub   CulDSac  ...           0             0         0
# 2         Lvl    AllPub    Inside  ...         151             0         0
# 3         Bnk    AllPub    Inside  ...           0             0         0
# 4         Lvl    AllPub   CulDSac  ...          18             0         0
#
#   ScreenPorch PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0         120       RL         60.0     4928   Pave  Grvl      IR1
# 1          20       RL         95.0    15865   Pave  Grvl      IR1
# 2          60       RL         92.0     9920   Pave  Grvl      IR1
# 3          20       RL        105.0    11751   Pave  Grvl      IR1
# 4          20       RL         60.0    16635   Pave  Grvl      IR1
#
#   LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 0         Lvl    AllPub    Inside  ...             0         0           0
# 1         Lvl    AllPub    Inside  ...             0         0         224
# 2         Lvl    AllPub   CulDSac  ...             0         0           0
# 3         Lvl    AllPub    Inside  ...             0         0           0
# 4         Lvl    AllPub       FR2  ...             0         0           0
#
#   PoolArea MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1168 entries, 0 to 1167
# Data columns (total 77 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1168 non-null   int64
#  1   MSZoning       1168 non-null   object
#  2   LotFrontage    1168 non-null   float64
#  3   LotArea        1168 non-null   int64
#  4   Street         1168 non-null   object
#  5   Alley          1168 non-null   object
#  6   LotShape       1168 non-null   object
#  7   LandContour    1168 non-null   object
#  8   Utilities      1168 non-null   object
#  9   LotConfig      1168 non-null   object
#  10  LandSlope      1168 non-null   object
#  11  Neighborhood   1168 non-null   object
#  12  Condition1     1168 non-null   object
#  13  Condition2     1168 non-null   object
#  14  BldgType       1168 non-null   object
#  15  HouseStyle     1168 non-null   object
#  16  OverallQual    1168 non-null   int64
# ...

# %%
for col in df.columns:
    if df[col].dtypes=='float64':
        df[col].fillna(df[col].mode()[0],inplace=True)

# %%
df.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1168.000000  1168.000000    1168.000000  1168.000000  1168.000000
# mean     56.767979    68.975171   10484.749144     6.104452     5.595890
# std      41.940650    22.836520    8957.442311     1.390153     1.124343
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    60.000000    7621.500000     5.000000     5.000000
# 50%      50.000000    64.000000    9522.500000     6.000000     5.000000
# 75%      70.000000    79.250000   11515.500000     7.000000     6.000000
# max     190.000000   313.000000  164660.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1168.000000   1168.000000  1168.000000  1168.000000  1168.000000  ...
# mean   1970.930651   1984.758562   101.696918   444.726027    46.647260  ...
# std      30.145255     20.785185   182.218483   462.664785   163.520016  ...
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=False,linewidths=0.1,linecolor="black")
# Out:
# <AxesSubplot:>

# %%
for col in df.columns:
    if df[col].dtypes=='object':
        sns.countplot(df[col])
        plt.xticks(rotation=90)
        plt.show()

# %%
for col in df.columns:
    if df[col].dtypes=='int64':
        sns.distplot(df[col])
        plt.xticks(rotation=90)
        plt.show()

# %%
import matplotlib.pyplot as plt
for col in df.columns:
    plt.scatter(x=df[col],y=df["SalePrice"])
    plt.xlabel(col)
    plt.ylabel("SalePrice")
    plt.xticks(rotation=90)
    plt.show()

# %%
#Label Encoding
import pandas as pd
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
for col in df.columns:
    if df[col].dtypes=="object":
        df[col]=LE.fit_transform(df[col])
df.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0         120         3         60.0     4928       1      2         0
# 1          20         3         95.0    15865       1      2         0
# 2          60         3         92.0     9920       1      2         0
# 3          20         3        105.0    11751       1      2         0
# 4          20         3         60.0    16635       1      2         0
#
#    LandContour  Utilities  LotConfig  ...  EnclosedPorch  3SsnPorch  \
# 0            3          0          4  ...              0          0
# 1            3          0          4  ...              0          0
# 2            3          0          1  ...              0          0
# 3            3          0          4  ...              0          0
# 4            3          0          2  ...              0          0
#
#    ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  SaleType  SaleCondition  \
# ...

# %%
#Label Encoding for test dataset
import pandas as pd
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
for col in df_test.columns:
    if df_test[col].dtypes=="object":
        df_test[col]=LE.fit_transform(df_test[col])
df_test.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0          20         2         86.0    14157       1      0         0
# 1         120         2          NaN     5814       1      0         0
# 2          20         2          NaN    11838       1      0         3
# 3          70         2         75.0    12000       1      0         3
# 4          60         2         86.0    14598       1      0         0
#
#    LandContour  Utilities  LotConfig  ...  OpenPorchSF  EnclosedPorch  \
# 0            1          0          0  ...           51              0
# 1            3          0          1  ...            0              0
# 2            3          0          4  ...          151              0
# 3            0          0          4  ...            0              0
# 4            3          0          1  ...           18              0
#
#    3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  SaleType  \
# ...

# %%
for col in df_test.columns:
    if df_test[col].dtypes=='float64':
        df_test[col].fillna(df_test[col].mode()[0],inplace=True)
df_test.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0          20         2         86.0    14157       1      0         0
# 1         120         2         60.0     5814       1      0         0
# 2          20         2         60.0    11838       1      0         3
# 3          70         2         75.0    12000       1      0         3
# 4          60         2         86.0    14598       1      0         0
#
#    LandContour  Utilities  LotConfig  ...  OpenPorchSF  EnclosedPorch  \
# 0            1          0          0  ...           51              0
# 1            3          0          1  ...            0              0
# 2            3          0          4  ...          151              0
# 3            0          0          4  ...            0              0
# 4            3          0          1  ...           18              0
#
#    3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  SaleType  \
# ...

# %%
#Checking for Outliers
df.plot(kind='box',subplots=True,figsize=(15,15),layout=(8,10))
# Out:
# MSSubClass          AxesSubplot(0.125,0.799681;0.065678x0.0803191)
# MSZoning         AxesSubplot(0.203814,0.799681;0.065678x0.0803191)
# LotFrontage      AxesSubplot(0.282627,0.799681;0.065678x0.0803191)
# LotArea          AxesSubplot(0.361441,0.799681;0.065678x0.0803191)
# Street           AxesSubplot(0.440254,0.799681;0.065678x0.0803191)
#                                        ...
# MoSold              AxesSubplot(0.282627,0.125;0.065678x0.0803191)
# YrSold              AxesSubplot(0.361441,0.125;0.065678x0.0803191)
# SaleType            AxesSubplot(0.440254,0.125;0.065678x0.0803191)
# SaleCondition       AxesSubplot(0.519068,0.125;0.065678x0.0803191)
# SalePrice           AxesSubplot(0.597881,0.125;0.065678x0.0803191)
# Length: 77, dtype: object

# %%
X=df.drop("SalePrice",axis=1)
Y=df["SalePrice"]
X.shape
# Out:
# (1168, 76)

# %%
Y.shape
# Out:
# (1168,)

# %%
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)
X_scaled.shape[1]
# Out:
# 76

# %%
scaled_Testdata=scaler.fit_transform(df_test)
scaled_Testdata.shape[1]
# Out:
# 76

# %%
#Feature Selection:
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
pca=PCA()
principalComponents=pca.fit_transform(X_scaled)
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel("No of Components")
plt.ylabel("Variance %")
plt.show()

# %%
principalComponents=pca.fit_transform(scaled_Testdata)
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel("No of Components")
plt.ylabel("Variance %")
plt.show()

# %%
pca=PCA(n_components=30)
new_data=pca.fit_transform(X_scaled)
principal_x=pd.DataFrame(new_data)
principal_x
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.597380 -1.477101 -1.824953  0.368424  0.977729 -0.706553  0.939609
# 1     3.188124 -0.175456  5.030518 -1.114803 -0.794349  2.758910 -0.546732
# 2     2.748540 -0.006412  0.010488  1.989352 -0.234208  0.724446 -0.807198
# 3     2.085072 -0.447574  1.824671 -1.868169  0.926491 -2.903248 -1.123108
# 4     1.771999 -1.633341  2.032540  0.263165  0.453135 -0.873836 -0.137923
# ...        ...       ...       ...       ...       ...       ...       ...
# 1163 -3.601193 -1.516575  0.021539  0.067902 -0.285402 -1.135475 -1.095420
# 1164 -2.527111  0.484173 -2.560594 -1.839607 -1.053205  0.596294 -0.493334
# 1165 -0.930178 -0.312909 -1.549703  3.841304  1.054421 -0.938867  0.905671
# 1166 -6.074410  3.564801  0.468773  0.539557  2.223201 -0.575667  2.715252
# 1167  2.269999 -0.022687 -1.674573  1.145915 -1.662817  1.040533 -0.033625
#
# ...

# %%
pca=PCA(n_components=30)
new_data=pca.fit_transform(scaled_Testdata)
principal_TestData=pd.DataFrame(new_data)
principal_TestData
# Out:
#            0         1         2         3         4         5         6   \
# 0    6.254878  2.463475  1.021799 -1.877979  0.699608  0.366046  0.851527
# 1    0.892605  3.468849 -1.828734  1.708746  1.271642  5.903979 -0.200981
# 2    4.038984 -0.130542  0.122200 -3.360564 -0.180509  0.379498 -1.021711
# 3   -2.031035 -1.535103  1.239848  0.144613 -0.432266 -0.910246  0.801629
# 4    3.436525 -3.043946  0.053006 -0.859489 -0.530274 -0.199330 -0.244604
# ..        ...       ...       ...       ...       ...       ...       ...
# 287  3.540309 -0.022299 -0.007291 -2.682097 -0.867327  0.445825 -1.512826
# 288 -0.985719  1.086089 -1.500388 -0.711274 -1.806970 -0.732241 -0.191007
# 289 -0.566385  1.990648 -0.580951  0.357160 -1.643168 -0.502492  0.868529
# 290 -2.325910 -0.658635  1.447639  0.761537 -0.596524  0.392263  0.949272
# 291 -4.043057 -1.761515 -3.237485  3.214918  0.496043  0.162554  1.226981
#
#            7         8         9   ...        20        21        22  \
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(principal_x,Y,test_size=0.30,random_state=34)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score

# %%
for i in range(1,100):
    X_train,X_test,Y_train,Y_test=train_test_split(principal_x,Y,test_size=0.30,random_state=i)
    lr.fit(X_train,Y_train)
    pred_train=lr.predict(X_train)
    pred_test=lr.predict(X_test)
    
    print(f"At random state {i}, the training accuracy is : {r2_score(Y_train,pred_train)}")
    print(f"At random state {i}, the testing accuracy is : {r2_score(Y_test,pred_test)}")
    print("\n")
# Out:
# At random state 1, the training accuracy is : 0.7951938256457082
# At random state 1, the testing accuracy is : 0.815032980507107
#
#
# At random state 2, the training accuracy is : 0.8205195428803953
# At random state 2, the testing accuracy is : 0.751358935869964
#
#
# At random state 3, the training accuracy is : 0.7828439409037484
# At random state 3, the testing accuracy is : 0.8499756632069896
#
#
# At random state 4, the training accuracy is : 0.834160740864373
# At random state 4, the testing accuracy is : 0.6850898364095053
#
#
# At random state 5, the training accuracy is : 0.8751345229449494
# At random state 5, the testing accuracy is : 0.5894101983134583
#
#
# At random state 6, the training accuracy is : 0.7890207990430558
# At random state 6, the testing accuracy is : 0.8344888363837935
#
#
# At random state 7, the training accuracy is : 0.8091223068229072
# At random state 7, the testing accuracy is : 0.7624896513293526
#
#
# ...

# %%
#At random state 88, the training accuracy is : 0.7737153972651983
#At random state 88, the testing accuracy is : 0.8650195597067971
X_train,X_test,Y_train,Y_test=train_test_split(principal_x,Y,test_size=0.30,random_state=88)
lr.fit(X_train,Y_train)
pred_train=lr.predict(X_train)
pred_test=lr.predict(X_test)
    
print(f"At random state 88, the training accuracy is : {r2_score(Y_train,pred_train)}")
print(f"At random state 88, the testing accuracy is : {r2_score(Y_test,pred_test)}")
# Out:
# At random state 88, the training accuracy is : 0.7737153972651983
# At random state 88, the testing accuracy is : 0.8650195597067971

# %%
Testingaccuracy=r2_score(Y_test,pred_test)

from sklearn.model_selection import cross_val_score
cv_score=cross_val_score(lr,principal_x,Y,cv=10)
cv_mean=cv_score.mean()
print(f"the cv_score is {cv_mean}, Test accuracy{Testingaccuracy}")
# Out:
# the cv_score is 0.7705553980448396, Test accuracy0.8650195597067971

# %%
import matplotlib.pyplot as plt
plt.scatter(Y_test,pred_test)
plt.xlabel('Sale Price')
plt.ylabel('Predicted Sale Price')
plt.show()

# %%
#Regularisation & Hyperparameter Tuning
from sklearn.linear_model import Ridge,Lasso,RidgeCV,LassoCV
from sklearn.model_selection import GridSearchCV,cross_val_score
import warnings
warnings.filterwarnings('ignore')

parameters={'alpha':[.001,.01,-1,1,10]}
lasso=Lasso()
clf=GridSearchCV(lasso,parameters)
clf.fit(X_train,Y_train)
print(clf.best_params_)
# Out:
# {'alpha': 10}

# %%
lassocv=LassoCV(alphas=None,max_iter=100,normalize=True)
lassocv.fit(X_train,Y_train)
# Out:
# LassoCV(max_iter=100, normalize=True)

# %%
alpha=lassocv.alpha_
alpha
# Out:
# 164.17827037379655

# %%
lassoreg=Lasso(alpha)
lassoreg.fit(X_train,Y_train)
# Out:
# Lasso(alpha=164.17827037379655)

# %%
lassoreg.score(X_test,Y_test)
# Out:
# 0.8645217571148999

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor,GradientBoostingRegressor

model=[DecisionTreeRegressor(),KNeighborsRegressor(),AdaBoostRegressor(),GradientBoostingRegressor()]
max_r2=0
for rstate in range(40,90):
    X_train,X_test,Y_train,Y_test=train_test_split(principal_x,Y,test_size=0.33,random_state=rstate)
    for i in model:
        i.fit(X_train,Y_train)
        pred_train=i.predict(X_train)
        pred_test=i.predict(X_test)
        r2=r2_score(Y_test,pred_test)
        print("R2 score correspond to Random state", rstate,"is", r2)
        if r2>max_r2:
                    max_r2=r2
                    finalstate=rstate
                    finalmodel=i
print("Max R2score correspond to randomstate", finalstate, "is", max_r2, "and the model is",finalmodel )
# Out:
# R2 score correspond to Random state 40 is 0.6642095662945547
# R2 score correspond to Random state 40 is 0.7242223991484888
# R2 score correspond to Random state 40 is 0.7464923899409134
# R2 score correspond to Random state 40 is 0.8298668742769577
# R2 score correspond to Random state 41 is 0.5519562985701653
# R2 score correspond to Random state 41 is 0.6705419502682946
# R2 score correspond to Random state 41 is 0.7621284153363881
# R2 score correspond to Random state 41 is 0.8226234261228447
# R2 score correspond to Random state 42 is 0.7086163081372021
# R2 score correspond to Random state 42 is 0.731659415651639
# R2 score correspond to Random state 42 is 0.780755685283647
# R2 score correspond to Random state 42 is 0.8055176464237304
# R2 score correspond to Random state 43 is 0.771585128757077
# R2 score correspond to Random state 43 is 0.7077261113050682
# R2 score correspond to Random state 43 is 0.7658298682448689
# ...

# %%
#Max R2score correspond to randomstate 84 is 0.8920485507692786 and the model is GradientBoostingRegressor()
X_train,X_test,Y_train,Y_test=train_test_split(principal_x,Y,test_size=0.33,random_state=84)
gdr=GradientBoostingRegressor()
gdr.fit(X_train,Y_train)
pred_train=gdr.predict(X_train)
pred_test=gdr.predict(X_test)
r2=r2_score(Y_test,pred_test)
print("R2 score is", r2)
# Out:
# R2 score is 0.884823337733549

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error 
import pandas as pd
MAE= mean_absolute_error(Y_test,pred_test)
print("Mean Absolute Error:",MAE)

MSE=mean_squared_error(Y_test,pred_test)
print("Mean Squared Error:",MSE)

print("Root Mean Squared Error:", np.sqrt(mean_squared_error(Y_test,pred_test)))
# Out:
# Mean Absolute Error: 18278.74237338939
# Mean Squared Error: 892346106.9072987
# Root Mean Squared Error: 29872.162742381053

# %%
import pickle
file=open('Housing Project.pkl','wb')

# %%
pickle.dump(gdr,file)

# %%
model=open('Housing Project.pkl','rb')
HousingPricePrediction=pickle.load(model)

# %%
pred_test=gdr.predict(principal_TestData)

# %%
pred_test
# Out:
# array([342822.02489713, 192330.69335503, 264206.32080616, 138115.96765186,
#        272535.58089339,  84422.76116135, 146307.87508287, 322359.84478634,
#        267514.46465205, 181700.82218581, 107091.33327018, 155892.593633  ,
#        150537.38349871, 256717.09857172, 313053.70031538, 112328.715181  ,
#        145905.59740626, 142780.93002748, 185119.71259071, 175717.93188565,
#        120618.83617076, 160095.42146176, 153967.54273529,  88943.19518723,
#         94851.91486659, 147908.86361915, 182390.34865738, 148225.34232407,
#        164522.3400853 , 108068.52298253, 141647.59635558, 199416.96892869,
#        263207.90919761, 207430.28857895,  93911.89410777, 184832.99611977,
#        184200.95039456, 103060.76656928, 142184.40586664, 132628.52206172,
#        104620.52680731, 306253.17276248, 198092.68940601, 182806.21312527,
#        141469.91560663, 112370.91132728, 139414.37409881,  95966.74817321,
# ...

# %%
df = pd.DataFrame(pred_test)
df.to_excel(excel_writer=r"C:\Users\hp\Datascience\House Price Prediction.xlsx")
